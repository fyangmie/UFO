# %% [markdown]
# # UFO Country Predictor Training Notebook
#
# This notebook mirrors the reproducible training script in `scripts/train_model.py`.

# %%
import pandas as pd

df = pd.read_csv('../data/ufos.csv')
df = df[['duration (seconds)', 'country', 'latitude', 'longitude']].rename(columns={
    'duration (seconds)': 'Seconds',
    'country': 'Country',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
})
df.head()

# %% [markdown]
# Run `python scripts/train_model.py` from the repository root to regenerate `models/ufo-model.pkl` and `models/label_mapping.json`.
